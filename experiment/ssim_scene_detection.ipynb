# %%
import cv2
from skimage.metrics import structural_similarity as ssim
import numpy as np
from tqdm import tqdm
# --- Parameters ---
video_path = "input_video.mp4"
ssim_threshold = 0.90  # Keep frame if SSIM with previous saved frame < threshold
def ssim_sampling(video_path):
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    prev_gray = None
    frame_idx = 0
    sampled_frames = []  # List to store frames
    with tqdm(total= total_frames, desc="Processing Frames") as pbar:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            
            # Always save first frame
            if prev_gray is None:
                sampled_frames.append(frame)
                prev_gray = gray
                frame_idx += 1
                continue
            if frame_idx % int(fps) != 0:
                frame_idx +=1 
                pbar.update(1)
                continue
            score = ssim(prev_gray, gray)            
            if score < ssim_threshold:
                sampled_frames.append(frame)
                prev_gray = gray  # Update previous frame


            frame_idx += 1
            pbar.update(1)

    cap.release()
    print(f"Sampled {len(sampled_frames)} frames from the video.")

# %%
ssim_sampling("../This Integral Breaks Math.mp4")
# Out:
# Processing Frames: 100%|█████████▉| 7792/7793 [03:01<00:00, 42.99it/s]
# Sampled 227 frames from the video.

# %%
import cv2
from skimage.metrics import structural_similarity as ssim
import numpy as np


ssim_threshold = 0.90  # Keep frame if SSIM with previous saved frame < threshold
def ssim_sampling(video_path):
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    frame_no = 0
    prev_gray = None
    frame_idx = 0
    sampled_frames = []  # List to store frames
    
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        # Always save first frame
        if prev_gray is None:
            sampled_frames.append(frame)
            prev_gray = gray
            frame_idx += 1
            continue
        
        score = ssim(prev_gray, gray)
        
        if frame_no % int(round(fps)) == 0:
            
            if score < ssim_threshold:
                sampled_frames.append(frame)
                prev_gray = gray  # Update previous frame

            

        frame_idx += 1

    cap.release()
    print(f"Sampled {len(sampled_frames)} frames from the video.")
